# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# export_graphviz: 나무 구조 생성 및 저장 
from sklearn.tree import export_graphviz
# graphviz : 나무 구조 시각화  (.dot 확장자 파일 불러오기 등)
import graphviz
# 데이터 분할:train, test
from sklearn.model_selection import train_test_split
# 예측/회귀 Decision Tree
from sklearn.tree import DecisionTreeRegressor
# 최적 모델, 파라미터 탐색
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv('/Users/yunsang-il/Downloads/df_raw.csv', encoding='euc-kr')
df.head()
# Out:
#                                Name    Location     Price  Year  \
# 0            Maruti Wagon R LXI CNG      Mumbai   2682.68  2010
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  19162.00  2015
# 2                      Honda Jazz V     Chennai   6898.32  2011
# 3                 Maruti Ertiga VDI     Chennai   9197.76  2012
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  27194.71  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              72000       CNG       Manual      First     26.0   998.0
# 1              41000    Diesel       Manual      First     19.0  1582.0
# 2              46000    Petrol       Manual      First     18.0  1199.0
# 3              87000    Diesel       Manual      First     20.0  1248.0
# 4              40670    Diesel    Automatic     Second     15.0  1968.0
#
#    Power  Seats  New_Price Price_Category  Price_per_KM  Price_Growth
# 0   58.0    5.0        NaN            Low      0.037259           NaN
# ...

# %%
df.drop(labels=['Price_Category', 'Price_per_KM', 'Price_Growth'], axis=1, inplace=True)

# %%
df
# Out:
#                                                    Name    Location     Price  \
# 0                                Maruti Wagon R LXI CNG      Mumbai   2682.68
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  19162.00
# 2                                          Honda Jazz V     Chennai   6898.32
# 3                                     Maruti Ertiga VDI     Chennai   9197.76
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  27194.71
# ...                                                 ...         ...       ...
# 7247                  Volkswagen Vento Diesel Trendline   Hyderabad       NaN
# 7248                             Volkswagen Polo GT TSI      Mumbai       NaN
# 7249                             Nissan Micra Diesel XV     Kolkata       NaN
# 7250                             Volkswagen Polo GT TSI        Pune       NaN
# 7251  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi       NaN
#
# ...

# %% [markdown]
# # 데이터 결측치 확인

# %%
df.isnull().sum()
# Out:
# Name                    0
# Location                0
# Price                1053
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                   0
# Seats                   0
# New_Price            6246
# dtype: int64

# %% [markdown]
# # mileage 결측치 확인

# %%
df['Mileage'].head()
# Out:
# 0    26.0
# 1    19.0
# 2    18.0
# 3    20.0
# 4    15.0
# Name: Mileage, dtype: float64

# %% [markdown]
# # 단위 지우기

# %%
dele = df['Mileage'].str.replace('kmpl', '')
df['Mileage'] = dele
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 dele = df['Mileage'].str.replace('kmpl', '')
#       2 df['Mileage'] = dele
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %% [markdown]
# # float로 바꾸기

# %%
asdfasdf = df['Mileage'].astype(float)
df['Mileage'] = asdfasdf

# %% [markdown]
# # 결측치 데이터 출력

# %%
qwerqwer = df[df['Mileage'].isnull()]
qwerqwer
# Out:
#                            Name Location     Price  Year  Kilometers_Driven  \
# 4446       Mahindra E Verito D4  Chennai  19928.48  2016              50000
# 4904  Toyota Prius 2009-2016 Z4   Mumbai  19545.24  2011              44000
#
#      Fuel_Type Transmission Owner_Type  Mileage   Engine   Power  Seats  \
# 4446  Electric    Automatic      First      NaN    72 CC  41 bhp    5.0
# 4904  Electric    Automatic      First      NaN  1798 CC  73 bhp    5.0
#
#        New_Price
# 4446  13.58 Lakh
# 4904         NaN

# %% [markdown]
# # 결측치 평균값으로 변경

# %%
df.loc[df['Mileage'] != df['Mileage'], 'Mileage'] = df['Mileage'].mean()
df['Mileage']
# Out:
# 0       26.60
# 1       19.67
# 2       18.20
# 3       20.77
# 4       15.20
#         ...
# 7248    20.54
# 7249    17.21
# 7250    23.08
# 7251    17.20
# 7252    10.00
# Name: Mileage, Length: 7253, dtype: float64

# %% [markdown]
# # Seats 결측치 확인

# %%
missing_price_data = df[df['Seats'].isnull()]

# 결측치 데이터 출력
missing_price_data
# Out:
#                                               Name    Location     Price  \
# 194                             Honda City 1.5 GXI   Ahmedabad   4522.23
# 208                           Maruti Swift 1.3 VXi     Kolkata   3234.55
# 229                               Ford Figo Diesel   Bangalore   5518.66
# 733                           Maruti Swift 1.3 VXi     Chennai   2682.68
# 749                   Land Rover Range Rover 3.0 D      Mumbai  40623.44
# 1294                             Honda City 1.3 DX       Delhi   4905.47
# 1327                          Maruti Swift 1.3 ZXI   Hyderabad   8891.17
# 1385                            Honda City 1.5 GXI        Pune   2299.44
# 1460  Land Rover Range Rover Sport 2005 2012 Sport  Coimbatore  62667.40
# 1917                            Honda City 1.5 EXI      Jaipur   2606.03
# 2074                          Maruti Swift 1.3 LXI        Pune   4828.82
# 2096                     Hyundai Santro LP zipPlus  Coimbatore   2958.61
# ...

# %% [markdown]
# # 차량 이름에서 브랜드만 추출해 파생변수 생성

# %%
df['Brand'] = df['Name'].apply(lambda x : x.split()[0])
df['Brand']
# Out:
# 0              Maruti
# 1             Hyundai
# 2               Honda
# 3              Maruti
# 4                Audi
#             ...
# 7248       Volkswagen
# 7249       Volkswagen
# 7250           Nissan
# 7251       Volkswagen
# 7252    Mercedes-Benz
# Name: Brand, Length: 7253, dtype: object

# %% [markdown]
# # 현재 연도를 기준으로 차량 연식 계산해서 파생변수 생성

# %%
df['Year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7253 entries, 0 to 7252
# Series name: Year
# Non-Null Count  Dtype
# --------------  -----
# 7253 non-null   int64
# dtypes: int64(1)
# memory usage: 56.8 KB

# %%
df['New_Year'] = 2024 - df['Year']
df
# Out:
#                                                    Name    Location     Price  \
# 0                                Maruti Wagon R LXI CNG      Mumbai   2682.68
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  19162.00
# 2                                          Honda Jazz V     Chennai   6898.32
# 3                                     Maruti Ertiga VDI     Chennai   9197.76
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  27194.71
# ...                                                 ...         ...       ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad       NaN
# 7249                             Volkswagen Polo GT TSI      Mumbai       NaN
# 7250                             Nissan Micra Diesel XV     Kolkata       NaN
# 7251                             Volkswagen Polo GT TSI        Pune       NaN
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi       NaN
#
# ...

# %% [markdown]
# # 요약통계량 확인

# %%
df.describe()
# Out:
#                Price         Year  Kilometers_Driven      Mileage  \
# count    6200.000000  7253.000000       7.253000e+03  7253.000000
# mean    14912.514750  2013.365366       5.869906e+04    18.141580
# std     17674.318464     3.254421       8.442772e+04     4.561567
# min         7.080000  1996.000000       1.710000e+02     0.000000
# 25%      5365.360000  2011.000000       3.400000e+04    15.170000
# 50%      8814.520000  2014.000000       5.341600e+04    18.160000
# 75%     15869.972500  2016.000000       7.300000e+04    21.100000
# max    245273.600000  2019.000000       6.500000e+06    33.540000
#
#              Seats     New_Year
# count  7200.000000  7253.000000
# mean      5.279722    10.634634
# std       0.811660     3.254421
# min       0.000000     5.000000
# 25%       5.000000     8.000000
# 50%       5.000000    10.000000
# 75%       5.000000    13.000000
# max      10.000000    28.000000

# %%
df.describe(include='all')
# Out:
#                           Name Location          Price         Year  \
# count                     7253     7253    6200.000000  7253.000000
# unique                    2041       11            NaN          NaN
# top     Mahindra XUV500 W8 2WD   Mumbai            NaN          NaN
# freq                        55      949            NaN          NaN
# mean                       NaN      NaN   14912.514750  2013.365366
# std                        NaN      NaN   17674.318464     3.254421
# min                        NaN      NaN       7.080000  1996.000000
# 25%                        NaN      NaN    5365.360000  2011.000000
# 50%                        NaN      NaN    8814.520000  2014.000000
# 75%                        NaN      NaN   15869.972500  2016.000000
# max                        NaN      NaN  245273.600000  2019.000000
#
#         Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage  \
# count        7.253000e+03      7253         7253       7253  7253.000000
# ...

# %%
df
# Out:
#                                                    Name    Location     Price  \
# 0                                Maruti Wagon R LXI CNG      Mumbai   2682.68
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  19162.00
# 2                                          Honda Jazz V     Chennai   6898.32
# 3                                     Maruti Ertiga VDI     Chennai   9197.76
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  27194.71
# ...                                                 ...         ...       ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad       NaN
# 7249                             Volkswagen Polo GT TSI      Mumbai       NaN
# 7250                             Nissan Micra Diesel XV     Kolkata       NaN
# 7251                             Volkswagen Polo GT TSI        Pune       NaN
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi       NaN
#
# ...

# %%
# df.isnull().sum()
# Out:
# Name                    0
# Location                0
# Price                1053
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Brand                   0
# New_Year                0
# dtype: int64

# %%
# df.to_csv()
